# %%
from pymongo import MongoClient
import pandas as pd
import geopandas as gpd
import json

import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# ## Importing MongoDB information:

# %%
client = MongoClient("localhost:27017")

# %%
db = client.get_database("lab-mongo-queries")

# %%
companies = db.get_collection("companies")

# %%
companies.find_one()
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#  'name': 'Wetpaint',
#  'permalink': 'abc2',
#  'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#  'homepage_url': 'http://wetpaint-inc.com',
#  'blog_url': 'http://digitalquarters.net/',
#  'blog_feed_url': 'http://digitalquarters.net/feed/',
#  'twitter_username': 'BachelrWetpaint',
#  'category_code': 'web',
#  'number_of_employees': 47,
#  'founded_year': 2005,
#  'founded_month': 10,
#  'founded_day': 17,
#  'deadpooled_year': 1,
#  'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#  'alias_list': '',
#  'email_address': 'info@wetpaint.com',
#  'phone_number': '206.859.6300',
#  'description': 'Technology Platform Company',
#  'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#  'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
#  'overview': '<p>Wetpaint is a technology platform company that uses its proprietary state-of-the-art technology and expertise in social media to build and monetize audiences for digital publishers. Wetpaint’s own online property, Wetpaint Entertainment, an entertainment news site that attracts more than 12 million unique visitors monthly and has over 2 million Facebook fans, is a proof point to the company’s success in building and engaging audiences. Media companies can license Wetpaint’s platform which includes a dynamic playbook tailored to their individual needs and comprehensive training. Founded by Internet pioneer Ben Elowitz, and with offices in New York and Seattle, Wetpaint is backed by Accel Partners, the investors behind Facebook.</p>',
#  'image': {'available_sizes': [[[150, 75],
#     'assets/images/resized/0000/3604/3604v14-max-150x150.jpg'],
#    [[250, 125], 'assets/images/resized/0000/3604/3604v14-max-250x250.jpg'],
#    [[450, 225], 'assets/images/resized/0000/3604/3604v14-max-450x450.jpg']]},
#  'products': [{'name': 'Wikison Wetpaint', 'permalink': 'wetpaint-wiki'},
#   {'name': 'Wetpaint Social Distribution System',
#    'permalink': 'wetpaint-social-distribution-system'}],
#  'relationships': [{'is_past': False,
#    'title': 'Co-Founder and VP, Social and Audience Development',
#    'person': {'first_name': 'Michael',
#     'last_name': 'Howell',
#     'permalink': 'michael-howell'}},
#   {'is_past': False,
#    'title': 'Co-Founder/CEO/Board of Directors',
#    'person': {'first_name': 'Ben',
#     'last_name': 'Elowitz',
#     'permalink': 'ben-elowitz'}},
#   {'is_past': False,
#    'title': 'COO/Board of Directors',
#    'person': {'first_name': 'Rob',
#     'last_name': 'Grady',
#     'permalink': 'rob-grady'}},
#   {'is_past': False,
#    'title': 'SVP, Strategy and Business Development',
#    'person': {'first_name': 'Chris',
#     'last_name': 'Kollas',
#     'permalink': 'chris-kollas'}},
#   {'is_past': False,
#    'title': 'Board',
#    'person': {'first_name': 'Theresia',
#     'last_name': 'Ranzetta',
#     'permalink': 'theresia-ranzetta'}},
#   {'is_past': False,
#    'title': 'Board Member',
#    'person': {'first_name': 'Gus',
#     'last_name': 'Tai',
#     'permalink': 'gus-tai'}},
#   {'is_past': False,
#    'title': 'Board',
#    'person': {'first_name': 'Len',
#     'last_name': 'Jordan',
#     'permalink': 'len-jordan'}},
#   {'is_past': False,
#    'title': 'Head of Technology and Product',
#    'person': {'first_name': 'Alex',
#     'last_name': 'Weinstein',
#     'permalink': 'alex-weinstein'}},
#   {'is_past': True,
#    'title': 'CFO',
#    'person': {'first_name': 'Bert',
#     'last_name': 'Hogue',
#     'permalink': 'bert-hogue'}},
#   {'is_past': True,
#    'title': 'CFO/ CRO',
#    'person': {'first_name': 'Brian',
#     'last_name': 'Watkins',
#     'permalink': 'brian-watkins'}},
#   {'is_past': True,
#    'title': 'Senior Vice President, Marketing',
#    'person': {'first_name': 'Rob',
#     'last_name': 'Grady',
#     'permalink': 'rob-grady'}},
#   {'is_past': True,
#    'title': 'VP, Technology and Product',
#    'person': {'first_name': 'Werner',
#     'last_name': 'Koepf',
#     'permalink': 'werner-koepf'}},
#   {'is_past': True,
#    'title': 'VP Marketing',
#    'person': {'first_name': 'Kevin',
#     'last_name': 'Flaherty',
#     'permalink': 'kevin-flaherty'}},
#   {'is_past': True,
#    'title': 'VP User Experience',
#    'person': {'first_name': 'Alex',
#     'last_name': 'Berg',
#     'permalink': 'alex-berg'}},
#   {'is_past': True,
#    'title': 'VP Engineering',
#    'person': {'first_name': 'Steve',
#     'last_name': 'McQuade',
#     'permalink': 'steve-mcquade'}},
#   {'is_past': True,
#    'title': 'Executive Editor',
#    'person': {'first_name': 'Susan',
#     'last_name': 'Mulcahy',
#     'permalink': 'susan-mulcahy'}},
#   {'is_past': True,
#    'title': 'VP Business Development',
#    'person': {'first_name': 'Chris',
#     'last_name': 'Kollas',
#     'permalink': 'chris-kollas'}}],
#  'competitions': [{'competitor': {'name': 'Wikia', 'permalink': 'wikia'}},
#   {'competitor': {'name': 'JotSpot', 'permalink': 'jotspot'}},
#   {'competitor': {'name': 'Socialtext', 'permalink': 'socialtext'}},
#   {'competitor': {'name': 'Ning by Glam Media', 'permalink': 'ning'}},
#   {'competitor': {'name': 'Soceeo', 'permalink': 'soceeo'}},
#   {'competitor': {'name': 'Yola', 'permalink': 'yola'}},
#   {'competitor': {'name': 'SocialGO', 'permalink': 'socialgo'}},
#   {'competitor': {'name': 'IslamNor', 'permalink': 'islamnor'}}],
#  'providerships': [],
#  'total_money_raised': '$39.8M',
#  'funding_rounds': [{'id': 888,
#    'round_code': 'a',
#    'source_url': 'http://seattlepi.nwsource.com/business/246734_wiki02.html',
#    'source_description': '',
#    'raised_amount': 5250000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2005,
#    'funded_month': 10,
#    'funded_day': 1,
#    'investments': [{'company': None,
#      'financial_org': {'name': 'Frazier Technology Ventures',
#       'permalink': 'frazier-technology-ventures'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Trinity Ventures',
#       'permalink': 'trinity-ventures'},
#      'person': None}]},
#   {'id': 889,
#    'round_code': 'b',
#    'source_url': 'http://pulse2.com/2007/01/09/wiki-builder-website-wetpaint-welcomes-95m-funding/',
#    'source_description': '',
#    'raised_amount': 9500000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2007,
#    'funded_month': 1,
#    'funded_day': 1,
#    'investments': [{'company': None,
#      'financial_org': {'name': 'Accel Partners',
#       'permalink': 'accel-partners'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Frazier Technology Ventures',
#       'permalink': 'frazier-technology-ventures'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Trinity Ventures',
#       'permalink': 'trinity-ventures'},
#      'person': None}]},
#   {'id': 2312,
#    'round_code': 'c',
#    'source_url': 'http://www.accel.com/news/news_one_up.php?news_id=185',
#    'source_description': 'Accel',
#    'raised_amount': 25000000,
#    'raised_currency_code': 'USD',
#    'funded_year': 2008,
#    'funded_month': 5,
#    'funded_day': 19,
#    'investments': [{'company': None,
#      'financial_org': {'name': 'DAG Ventures', 'permalink': 'dag-ventures'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Accel Partners',
#       'permalink': 'accel-partners'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Trinity Ventures',
#       'permalink': 'trinity-ventures'},
#      'person': None},
#     {'company': None,
#      'financial_org': {'name': 'Frazier Technology Ventures',
#       'permalink': 'frazier-technology-ventures'},
#      'person': None}]}],
#  'investments': [],
#  'acquisition': {'price_amount': 30000000,
#   'price_currency_code': 'USD',
#   'term_code': 'cash_and_stock',
#   'source_url': 'http://allthingsd.com/20131216/viggle-tries-to-bulk-up-its-social-tv-business-by-buying-wetpaint/?mod=atdtweet',
#   'source_description': ' Viggle Tries to Bulk Up Its Social TV Business by Buying Wetpaint',
#   'acquired_year': 2013,
#   'acquired_month': 12,
#   'acquired_day': 16,
#   'acquiring_company': {'name': 'Viggle', 'permalink': 'viggle'}},
#  'acquisitions': [],
#  'offices': [{'description': '',
#    'address1': '710 - 2nd Avenue',
#    'address2': 'Suite 1100',
#    'zip_code': '98104',
#    'city': 'Seattle',
#    'state_code': 'WA',
#    'country_code': 'USA',
#    'latitude': 47.603122,
#    'longitude': -122.333253},
#   {'description': '',
#    'address1': '270 Lafayette Street',
#    'address2': 'Suite 505',
#    'zip_code': '10012',
#    'city': 'New York',
#    'state_code': 'NY',
#    'country_code': 'USA',
#    'latitude': 40.7237306,
#    'longitude': -73.9964312}],
#  'milestones': [{'id': 5869,
#    'description': "Wetpaint named in Lead411's Hottest Seattle Companies list",
#    'stoned_year': 2010,
#    'stoned_month': 6,
#    'stoned_day': 8,
#    'source_url': 'http://www.lead411.com/seattle-companies.html',
#    'source_text': None,
#    'source_description': 'LEAD411 LAUNCHES "HOTTEST SEATTLE COMPANIES" AWARDS',
#    'stoneable_type': 'Company',
#    'stoned_value': None,
#    'stoned_value_type': None,
#    'stoned_acquirer': None,
#    'stoneable': {'name': 'Wetpaint', 'permalink': 'wetpaint'}},
#   {'id': 8702,
#    'description': 'Site-Builder Wetpaint Makes One For Itself, Using the Demand Media Playbook',
#    'stoned_year': 2010,
#    'stoned_month': 9,
#    'stoned_day': 6,
#    'source_url': 'http://mediamemo.allthingsd.com/20100906/site-builder-wetpaint-makes-one-for-itself-using-the-demand-media-playbook/',
#    'source_text': None,
#    'source_description': 'All Things D',
#    'stoneable_type': 'Company',
#    'stoned_value': None,
#    'stoned_value_type': None,
#    'stoned_acquirer': None,
#    'stoneable': {'name': 'Wetpaint', 'permalink': 'wetpaint'}}],
#  'video_embeds': [],
#  'screenshots': [{'available_sizes': [[[150, 86],
#      'assets/images/resized/0016/0929/160929v2-max-150x150.png'],
#     [[250, 143], 'assets/images/resized/0016/0929/160929v2-max-250x250.png'],
#     [[450, 258], 'assets/images/resized/0016/0929/160929v2-max-450x450.png']],
#    'attribution': None}],
#  'external_links': [{'external_url': 'http://www.geekwire.com/2011/rewind-ben-elowitz-wetpaint-ceo-building-type-media-company',
#    'title': 'GeekWire interview: Rewind - Ben Elowitz, Wetpaint CEO, on building a new type of media company'},
#   {'external_url': 'http://techcrunch.com/2012/06/17/search-and-social-how-two-will-soon-become-one/',
#    'title': 'Guest post by CEO Ben Elowitz in TechCrunch'},
#   {'external_url': 'http://allthingsd.com/20120516/what-to-expect-when-facebook-is-expecting-five-predictions-for-facebooks-first-public-year/',
#    'title': 'Guest post by CEO Ben Elowitz in AllThingsD'},
#   {'external_url': 'http://adage.com/article/digitalnext/facebook-biggest-player-advertising-s-540-billion-world/235708/',
#    'title': 'Guest post by CEO Ben Elowitz in AdAge'},
#   {'external_url': 'http://www.businessinsider.com/facebook-captures-14-percent-of-our-online-attention-but-only-4-percent-of-ad-spending-online-2012-6',
#    'title': 'Guest post by CEO Ben Elowitz in Business Insider'},
#   {'external_url': 'http://allfacebook.com/wetpaint-media-data_b75963',
#    'title': 'AllFacebook coverage of Wetpaint'},
#   {'external_url': 'http://adage.com/article/digital/celeb-site-wetpaint-shows-media-profit-facebook/237828/',
#    'title': 'Profile of Wetpaint in Ad Age'},
#   {'external_url': 'http://allthingsd.com/20121018/how-to-boost-your-facebook-traffic-tips-and-tricks-from-wetpaint/',
#    'title': 'Interview with Wetpaint CEO Ben Elowitz in All Things D'},
#   {'external_url': 'http://www.xconomy.com/seattle/2012/10/19/wetpaint-starts-licensing-its-facebook-based-media-distribution-tech/',
#    'title': 'Profile of Wetpaint in Xconomy'}],
#  'partners': []}

# %% [markdown]
# #### Now we filter down every company with offices in Spain:

# %%
filter_spain = {"offices.country_code": "ESP"}
proj = {"_id": 0, "name": 1, "category_code": 1, "offices.$": 1, "funding_rounds": 1}

# %%
spain_offices = list(companies.find(filter_spain, proj))

# %%
spain_offices[0].keys()
# Out:
# dict_keys(['name', 'category_code', 'funding_rounds', 'offices'])

# %%
len(spain_offices)
# Out:
# 218

# %% [markdown]
# #### Only 218 remain.

# %%
spain_offices[0]["offices"]
# Out:
# [{'description': 'Google Madrid',
#   'address1': 'Torre Picasso',
#   'address2': 'Plaza Pablo Ruiz Picasso 1',
#   'zip_code': '28020',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None}]

# %% [markdown]
# #### We make dataframe with each office longitude, latitude, raised amount and category code:

# %%
final_offices = []

for doc in spain_offices:
    name = doc["name"]
    category_code = doc["category_code"]
    count = 0
    
    for funds in doc["funding_rounds"]:
        try:
            count += funds["raised_amount"]
        except:
            None
    
    for of in doc["offices"]:
        lat = of["latitude"]
        lon = of["longitude"]
        
        dic = {"name": name, "category_code": category_code, "raised_amount": count, "location": {"type": "Point", "coordinates": [lat, lon]}}
        dic.update(of)
        final_offices.append(dic)

# %%
final_offices
# Out:
# [{'name': 'Google',
#   'category_code': 'search',
#   'raised_amount': 555182792,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Google Madrid',
#   'address1': 'Torre Picasso',
#   'address2': 'Plaza Pablo Ruiz Picasso 1',
#   'zip_code': '28020',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Truphone',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Tru Spain',
#   'address1': 'Gran Via, 6. 4th floor',
#   'address2': '',
#   'zip_code': '28013',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Brightcove',
#   'category_code': 'enterprise',
#   'raised_amount': 103100000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Avenida Diagonal 640',
#   'address2': 'planta 6',
#   'zip_code': '08017',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Negonation',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.463667, -3.74922]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.463667,
#   'longitude': -3.74922},
#  {'name': 'TokBox',
#   'category_code': 'messaging',
#   'raised_amount': 26000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona Office',
#   'address1': 'D00 BUILDING - P14-L11',
#   'address2': 'PL.Ernest Lluch i Martin, 5',
#   'zip_code': '',
#   'city': 'Barcelona, 08019',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Fon',
#   'category_code': 'mobile',
#   'raised_amount': 44000000,
#   'location': {'type': 'Point', 'coordinates': [40.530724, -3.632687]},
#   'description': '',
#   'address1': 'Calle Quintanavides 15',
#   'address2': '2-1',
#   'zip_code': '28050',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.530724,
#   'longitude': -3.632687},
#  {'name': 'eyeOS',
#   'category_code': 'enterprise',
#   'raised_amount': 1000000,
#   'location': {'type': 'Point', 'coordinates': [41.3854855, 2.1702872]},
#   'description': 'HQ',
#   'address1': 'La Rambla 140 4C',
#   'address2': '',
#   'zip_code': '08002',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3854855,
#   'longitude': 2.1702872},
#  {'name': 'Genoom',
#   'category_code': 'network_hosting',
#   'raised_amount': 80000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': None,
#   'address1': 'Gran Capitan 2-4',
#   'address2': '',
#   'zip_code': '08034',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': ']project-open[',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.383182, 2.163697]},
#   'description': '',
#   'address1': 'Ronda de Sant Antonã, 51, 1o 2a',
#   'address2': '',
#   'zip_code': '08011',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.383182,
#   'longitude': 2.163697},
#  {'name': 'EkoPLC',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': None,
#   'address1': 'Cecilio Metelo, 5',
#   'address2': '',
#   'zip_code': '07003',
#   'city': 'Palma de Mallorca',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Starfish Community Group',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.387917, 2.169919]},
#   'description': '',
#   'address1': 'Major de Sarria 11, 2-1',
#   'address2': '',
#   'zip_code': '08017',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.387917,
#   'longitude': 2.169919},
#  {'name': 'Pixoo',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.463667, -3.74922]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.463667,
#   'longitude': -3.74922},
#  {'name': 'Buongiorno',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4487974, -3.6697641]},
#   'description': 'Spain',
#   'address1': 'Calle Javier Ferrero 13-15',
#   'address2': '',
#   'zip_code': '28002',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4487974,
#   'longitude': -3.6697641},
#  {'name': 'The Orchard',
#   'category_code': None,
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Swotti',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.416741, -3.70325]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.416741,
#   'longitude': -3.70325},
#  {'name': 'AsesorSeguros',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.497716, -3.647842]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '28050',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.497716,
#   'longitude': -3.647842},
#  {'name': 'Allopass',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Spain',
#   'address1': 'VelÃ¡zquez 12, 7-8 planta',
#   'address2': '',
#   'zip_code': '28001',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Spain Holiday',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [36.732544, -4.381867]},
#   'description': 'HQ',
#   'address1': 'Paseo Cerrado de Calderon 13 local 21',
#   'address2': 'Cerrado de Calderon',
#   'zip_code': '29018',
#   'city': 'Malaga',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 36.732544,
#   'longitude': -4.381867},
#  {'name': 'eRepublik',
#   'category_code': 'games_video',
#   'raised_amount': 2750000,
#   'location': {'type': 'Point', 'coordinates': [40.43094, -3.6952896]},
#   'description': 'Office',
#   'address1': 'Almagro 22',
#   'address2': '',
#   'zip_code': '28010',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.43094,
#   'longitude': -3.6952896},
#  {'name': 'Trovit',
#   'category_code': 'ecommerce',
#   'raised_amount': 600000,
#   'location': {'type': 'Point', 'coordinates': [41.388769, 2.1299487]},
#   'description': '',
#   'address1': 'Diagonal 601, 9ª',
#   'address2': '',
#   'zip_code': '08028',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.388769,
#   'longitude': 2.1299487},
#  {'name': 'BMAT',
#   'category_code': None,
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.406335, 2.192023]},
#   'description': None,
#   'address1': 'Carrer de Llacuna 162',
#   'address2': '',
#   'zip_code': '08018',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.406335,
#   'longitude': 2.192023},
#  {'name': 'Splendia',
#   'category_code': 'web',
#   'raised_amount': 3000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Headquarters',
#   'address1': '2-4, Rambla de Catalunya',
#   'address2': '',
#   'zip_code': '08007',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'All-rankings',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '08223',
#   'city': 'Terrassa',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Spotify',
#   'category_code': 'music',
#   'raised_amount': 533240000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Eloy Gonzalo, 27, 6Âº',
#   'address2': '',
#   'zip_code': '28010',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'NotePub',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.416741, -3.70325]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.416741,
#   'longitude': -3.70325},
#  {'name': 'Friend2Friend',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'European Office',
#   'address1': 'RossellÃ³, 25 Baixos 2a',
#   'address2': '',
#   'zip_code': '08029',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Futurlink',
#   'category_code': 'mobile',
#   'raised_amount': 7624000,
#   'location': {'type': 'Point', 'coordinates': [41.396553, 2.189241]},
#   'description': '',
#   'address1': 'Passeig de Gracia 49',
#   'address2': '',
#   'zip_code': '08018',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.396553,
#   'longitude': 2.189241},
#  {'name': 'BlogUpp',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Adeje',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'VivoCom',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': None,
#   'address1': 'c/ Princesa, 31 2Âºder',
#   'address2': '',
#   'zip_code': '28008',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Wuapi',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.387917, 2.169919]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.387917,
#   'longitude': 2.169919},
#  {'name': 'Ipoki',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.371491, -8.39597]},
#   'description': None,
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'A CoruÃ±a',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.371491,
#   'longitude': -8.39597},
#  {'name': 'FeedzZ',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4722272, -3.6532523]},
#   'description': '',
#   'address1': 'Totana 2,3d',
#   'address2': '',
#   'zip_code': '28033',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4722272,
#   'longitude': -3.6532523},
#  {'name': 'Valoris',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': None,
#   'address1': 'Av. Diagonal 453 bis, 4',
#   'address2': '',
#   'zip_code': '08035',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'vLex',
#   'category_code': 'legal',
#   'raised_amount': 4000000,
#   'location': {'type': 'Point', 'coordinates': [41.392852, 2.168021]},
#   'description': 'VLEX HQ (Barcelona)',
#   'address1': 'Consell de Cent 334',
#   'address2': '',
#   'zip_code': 'E08009',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.392852,
#   'longitude': 2.168021},
#  {'name': 'Jobisjob',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.487094, 2.07732]},
#   'description': 'Jobisjob.com',
#   'address1': 'Avda. Alcalde Barnils, 64 - 68',
#   'address2': 'Sant Cugat del Valles',
#   'zip_code': '08174',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.487094,
#   'longitude': 2.07732},
#  {'name': 'Just Landed',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Calle Maestro Lasalle, 36',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'GeoMe',
#   'category_code': 'mobile',
#   'raised_amount': 300000,
#   'location': {'type': 'Point', 'coordinates': [41.387411, 2.168518]},
#   'description': 'HQ',
#   'address1': 'Rambla de Catalunya 77, 1B',
#   'address2': '',
#   'zip_code': '08007',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.387411,
#   'longitude': 2.168518},
#  {'name': 'Panda Security',
#   'category_code': 'security',
#   'raised_amount': 13820000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ',
#   'address1': 'Calle Buenos Aires, 12',
#   'address2': '',
#   'zip_code': '48001',
#   'city': 'Bilbao',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Q-go',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Q-go Spain',
#   'address1': 'Edificio Lexington',
#   'address2': 'C/Orense 85',
#   'zip_code': '28020',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Dieyes',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Juan Ramon Jimenez 3',
#   'address2': '',
#   'zip_code': '07008',
#   'city': 'Palma de Mallorca',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'SYSCOM',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.553845, -3.899508]},
#   'description': 'Madrid Office',
#   'address1': 'Rosa de Lima 1',
#   'address2': '',
#   'zip_code': '28290',
#   'city': 'Las Rozas',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.553845,
#   'longitude': -3.899508},
#  {'name': 'Pixelnews',
#   'category_code': 'enterprise',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Headquarters',
#   'address1': 'Calle Alonso Heredia, 4  2ÂºE',
#   'address2': '',
#   'zip_code': '282028',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Next Limit',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.455219, -3.650703]},
#   'description': 'Headquarters',
#   'address1': 'Ã\x81ngel Cavero 2',
#   'address2': '',
#   'zip_code': '28043',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.455219,
#   'longitude': -3.650703},
#  {'name': 'Forvo',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.3135579, -1.9820361]},
#   'description': 'San Sebastián',
#   'address1': '',
#   'address2': '',
#   'zip_code': '20006',
#   'city': 'San Sebastián',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.3135579,
#   'longitude': -1.9820361},
#  {'name': 'Veedia',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.456586, -3.647013]},
#   'description': 'Corporate Headquarters',
#   'address1': 'Calle Toronga 23',
#   'address2': '',
#   'zip_code': '28043',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.456586,
#   'longitude': -3.647013},
#  {'name': 'Cyloop',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.5288449, -3.6429907]},
#   'description': 'Madrid Office',
#   'address1': 'Avda. de Bruselas 38-B 4',
#   'address2': 'Alcobendas',
#   'zip_code': '28108',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.5288449,
#   'longitude': -3.6429907},
#  {'name': 'ipsojobs',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.406248, 2.163194]},
#   'description': 'World Headquarters',
#   'address1': 'Pi i Margall, 7',
#   'address2': 'baixos 2a',
#   'zip_code': '08024',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.406248,
#   'longitude': 2.163194},
#  {'name': 'e-contratos',
#   'category_code': 'web',
#   'raised_amount': 200000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Headquartes',
#   'address1': 'La Alameda, 14, 1C',
#   'address2': '',
#   'zip_code': '03803',
#   'city': 'Alcoy',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Solaiemes',
#   'category_code': 'public_relations',
#   'raised_amount': 685000,
#   'location': {'type': 'Point', 'coordinates': [40.382338, -3.773844]},
#   'description': 'Solaiemes Headquarter',
#   'address1': 'Av/ General Fanjul',
#   'address2': '2-Bis, office 3-5',
#   'zip_code': '28044',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.382338,
#   'longitude': -3.773844},
#  {'name': 'MEDDIA',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.4018094, 2.1815648]},
#   'description': 'Headquarters',
#   'address1': 'Av. Diagonal 237',
#   'address2': '',
#   'zip_code': '08013',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4018094,
#   'longitude': 2.1815648},
#  {'name': 'YouLynx',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Mobile / PC Convergence',
#   'address1': 'Sor Angela de la Cruz, 2 - 14th floor',
#   'address2': '',
#   'zip_code': '28020',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'mmCHANNEL',
#   'category_code': 'other',
#   'raised_amount': 2000000,
#   'location': {'type': 'Point', 'coordinates': [40.456204, -3.813122]},
#   'description': 'Headquarters',
#   'address1': 'C/ Joaquin Turina, 2',
#   'address2': 'Planta 1',
#   'zip_code': '28224',
#   'city': 'Pozuelo de Alarcon',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.456204,
#   'longitude': -3.813122},
#  {'name': 'LingusTV',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'World Headquarters',
#   'address1': 'c/Zamora, 40 Bajos 2a',
#   'address2': '',
#   'zip_code': '08191',
#   'city': 'Rubi (Barcelona)',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Videoplaza',
#   'category_code': 'advertising',
#   'raised_amount': 15920000,
#   'location': {'type': 'Point', 'coordinates': [40.4596242, -3.6923285]},
#   'description': 'Madrid',
#   'address1': 'Forum Business Center c/ Capitán Haya',
#   'address2': '1 planta 15 Edificio Eurocentro',
#   'zip_code': '28020',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4596242,
#   'longitude': -3.6923285},
#  {'name': 'AtelMedia',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.416741, -3.70325]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.416741,
#   'longitude': -3.70325},
#  {'name': 'Nuroa',
#   'category_code': 'search',
#   'raised_amount': 3000000,
#   'location': {'type': 'Point', 'coordinates': [41.3916792, 2.1775706]},
#   'description': 'Offices',
#   'address1': 'Carrer de Bailen 7',
#   'address2': '',
#   'zip_code': '08010',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3916792,
#   'longitude': 2.1775706},
#  {'name': 'Festuc',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.387917, 2.169919]},
#   'description': 'HQ',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.387917,
#   'longitude': 2.169919},
#  {'name': 'Qajack',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona Office',
#   'address1': 'Passatge de la Pau 10 Bis (1-2)',
#   'address2': '',
#   'zip_code': '08002',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Bioalma',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Headquarters',
#   'address1': 'Ronda de Poniente 4 Bajo C',
#   'address2': '',
#   'zip_code': '28760',
#   'city': 'Tres Cantos, Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Bermi Labs',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.538143, 2.452718]},
#   'description': 'Corporate Headquarters',
#   'address1': 'Passeig del Callao',
#   'address2': '',
#   'zip_code': '08301',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.538143,
#   'longitude': 2.452718},
#  {'name': 'YouGoDo',
#   'category_code': 'web',
#   'raised_amount': 100000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'YouGoDo HQ',
#   'address1': 'Las Mimosas Golf de Cabopino F4 P5 N25',
#   'address2': 'Marbella',
#   'zip_code': '29600',
#   'city': 'Malaga',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Synerquia',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ',
#   'address1': 'Via Laietana 36 1 3',
#   'address2': '',
#   'zip_code': '08003',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Digital Assets Deployment',
#   'category_code': 'ecommerce',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.42046, -3.678121]},
#   'description': 'Corporate Headquarters',
#   'address1': 'Doctor Castelo 10',
#   'address2': 'Local 1',
#   'zip_code': '28009',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.42046,
#   'longitude': -3.678121},
#  {'name': 'Daily Flat Rental',
#   'category_code': 'ecommerce',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.412323, -3.703248]},
#   'description': 'Central Office',
#   'address1': 'Lavapies 26 1A',
#   'address2': '',
#   'zip_code': '28012',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.412323,
#   'longitude': -3.703248},
#  {'name': 'Linkua',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona HQ',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Softonic',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona Headquarters',
#   'address1': 'Ed. Meridian C/ Rosselló i Porcel, 21, planta 12',
#   'address2': '',
#   'zip_code': '08016',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': '3scale',
#   'category_code': 'enterprise',
#   'raised_amount': 5000000,
#   'location': {'type': 'Point', 'coordinates': [41.406335, 2.192023]},
#   'description': '3scale SPAIN',
#   'address1': 'C/Napols 187, 8',
#   'address2': '',
#   'zip_code': '08013',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.406335,
#   'longitude': 2.192023},
#  {'name': 'Yerbabuena Software',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Office',
#   'address1': 'Alessandro Volta 2, Oficina 18',
#   'address2': '',
#   'zip_code': '29590',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Daily Flat Rental',
#   'category_code': 'ecommerce',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.412323, -3.703248]},
#   'description': 'Central Office',
#   'address1': 'Lavapies 26 1A',
#   'address2': '',
#   'zip_code': '28012',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.412323,
#   'longitude': -3.703248},
#  {'name': 'Linkua',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona HQ',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Softonic',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Barcelona Headquarters',
#   'address1': 'Ed. Meridian C/ Rosselló i Porcel, 21, planta 12',
#   'address2': '',
#   'zip_code': '08016',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': '3scale',
#   'category_code': 'enterprise',
#   'raised_amount': 5000000,
#   'location': {'type': 'Point', 'coordinates': [41.406335, 2.192023]},
#   'description': '3scale SPAIN',
#   'address1': 'C/Napols 187, 8',
#   'address2': '',
#   'zip_code': '08013',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.406335,
#   'longitude': 2.192023},
#  {'name': 'Yerbabuena Software',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Office',
#   'address1': 'Alessandro Volta 2, Oficina 18',
#   'address2': '',
#   'zip_code': '29590',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Zonablu Networks',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [38.349114, -0.48931]},
#   'description': 'Head office',
#   'address1': 'C. Maestro Gaztambide 2 3Âº C',
#   'address2': '',
#   'zip_code': '03004',
#   'city': 'Alicante',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 38.349114,
#   'longitude': -0.48931},
#  {'name': 'Uselabs',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.483253, 2.331805]},
#   'description': 'Barcelona Office',
#   'address1': 'Agricultura 16-18',
#   'address2': '2.9',
#   'zip_code': '08320',
#   'city': 'El Masnou',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.483253,
#   'longitude': 2.331805},
#  {'name': 'Modo Marketing',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [39.64073, -0.421944]},
#   'description': 'Spanish Office',
#   'address1': '',
#   'address2': 'Naquera',
#   'zip_code': '46119',
#   'city': 'Valencia',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 39.64073,
#   'longitude': -0.421944},
#  {'name': 'Widgadget',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.392701, 2.156538]},
#   'description': 'Headquarter',
#   'address1': '184 rossello at 1',
#   'address2': '',
#   'zip_code': '08008',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.392701,
#   'longitude': 2.156538},
#  {'name': 'Spaceblue',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [28.962064, -13.556529]},
#   'description': 'Spaceblue Headquarters',
#   'address1': 'Gongora 38',
#   'address2': '',
#   'zip_code': '35500',
#   'city': 'Arrecife',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 28.962064,
#   'longitude': -13.556529},
#  {'name': 'Olivos by Design',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [36.492548, -4.72689]},
#   'description': 'Head Office',
#   'address1': 'Mijas Costa',
#   'address2': '',
#   'zip_code': '289650',
#   'city': 'Malaga',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 36.492548,
#   'longitude': -4.72689},
#  {'name': 'Dilogs',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.4424496, 1.8619165]},
#   'description': 'Headquarters',
#   'address1': 'Moli nou 15',
#   'address2': '',
#   'zip_code': '08790',
#   'city': 'Gelida',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4424496,
#   'longitude': 1.8619165},
#  {'name': 'Abiquo',
#   'category_code': 'enterprise',
#   'raised_amount': 25560400,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Research & Development',
#   'address1': 'Avinguda Diagonal 435bis',
#   'address2': '4th Floor',
#   'zip_code': '08036',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Visual Coast Web Development',
#   'category_code': 'network_hosting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Central - Media lab',
#   'address1': 'C/ Sant Isidoro 1, Bajo',
#   'address2': '',
#   'zip_code': '08303',
#   'city': 'MatarÃ³ (Barcelona)',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Adoos',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.432883, -3.8166758]},
#   'description': 'Adoos Classifieds',
#   'address1': 'Calle Luis Garcia 5, 1 E',
#   'address2': 'Pozuelo de Alarcon',
#   'zip_code': '28223',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.432883,
#   'longitude': -3.8166758},
#  {'name': 'Vertical Social Networks',
#   'category_code': 'enterprise',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.41259, 2.143797]},
#   'description': 'World Headquarters',
#   'address1': '',
#   'address2': '',
#   'zip_code': '08023',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.41259,
#   'longitude': 2.143797},
#  {'name': 'doctor SIM',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Spain',
#   'address1': 'Serrano 216',
#   'address2': '1dcha',
#   'zip_code': '28016',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Wysiwyg',
#   'category_code': 'consulting',
#   'raised_amount': 190000,
#   'location': {'type': 'Point', 'coordinates': [40.4494619, -3.7077788]},
#   'description': 'WYSIWYG',
#   'address1': 'Calle Aranjuez 7',
#   'address2': '',
#   'zip_code': '28039',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4494619,
#   'longitude': -3.7077788},
#  {'name': 'Qapacity',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3953856, 2.1681311]},
#   'description': 'Barcelona Headquarters',
#   'address1': '91 Bruc',
#   'address2': '',
#   'zip_code': '08009',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3953856,
#   'longitude': 2.1681311},
#  {'name': 'Tractis',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3762002, 2.1897317]},
#   'description': 'Tractis',
#   'address1': 'Carrer Sant Miquel 122, 5Âº-3Âª',
#   'address2': '',
#   'zip_code': '08003',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3762002,
#   'longitude': 2.1897317},
#  {'name': 'metoCube',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4204601, -3.6781213]},
#   'description': 'Madrid office',
#   'address1': 'Doctor Castelo 10',
#   'address2': '',
#   'zip_code': '28009',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4204601,
#   'longitude': -3.6781213},
#  {'name': 'net-m',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'net mobile Spain SLU',
#   'address1': 'Gran Via 6, 4e',
#   'address2': '',
#   'zip_code': '28013',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'pomeloTV',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4367771, -3.6685036]},
#   'description': 'headquarters',
#   'address1': 'Marques de Monteagudo,18',
#   'address2': '',
#   'zip_code': '28028',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4367771,
#   'longitude': -3.6685036},
#  {'name': 'MediBANK',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4718534, -3.8203307]},
#   'description': 'Central',
#   'address1': 'Gobelas, 17',
#   'address2': '',
#   'zip_code': '28023',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4718534,
#   'longitude': -3.8203307},
#  {'name': 'Neurotic',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3887383, 2.1756189]},
#   'description': 'World Headquarters',
#   'address1': 'C/Ortigosa 14',
#   'address2': 'Planta 3 Despacho 25',
#   'zip_code': '08003',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3887383,
#   'longitude': 2.1756189},
#  {'name': 'Meytel',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4511364, -3.6096649]},
#   'description': '',
#   'address1': 'Villamiel de CÃ¡ceres 13',
#   'address2': '',
#   'zip_code': '28042',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4511364,
#   'longitude': -3.6096649},
#  {'name': 'Heralsoft',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.5222205, -5.665828]},
#   'description': 'Mini Office',
#   'address1': 'Rio Nervion 12',
#   'address2': '',
#   'zip_code': '33210',
#   'city': 'Gijon',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.5222205,
#   'longitude': -5.665828},
#  {'name': 'doonde',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.4063346, 2.1920231]},
#   'description': 'Haedquarters',
#   'address1': 'Llacuna 162',
#   'address2': '',
#   'zip_code': '08018',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4063346,
#   'longitude': 2.1920231},
#  {'name': 'Striker Manager',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.4063346, 2.1920231]},
#   'description': 'World Headquarters',
#   'address1': 'Llacuna 162',
#   'address2': '',
#   'zip_code': '08018',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4063346,
#   'longitude': 2.1920231},
#  {'name': 'Mapalia',
#   'category_code': 'enterprise',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Mapalia',
#   'address1': 'Edificio Ilgner, C8',
#   'address2': '',
#   'zip_code': '48902',
#   'city': 'Barakaldo',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Tengaged',
#   'category_code': 'games_video',
#   'raised_amount': 15000,
#   'location': {'type': 'Point', 'coordinates': [41.4241228, 2.1634249]},
#   'description': 'Main',
#   'address1': 'C/Pedrell',
#   'address2': '',
#   'zip_code': '08032',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4241228,
#   'longitude': 2.1634249},
#  {'name': 'Veeam Software',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Spain',
#   'address1': 'Calle de la Ribera del Loira, 46',
#   'address2': '',
#   'zip_code': '28042',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'GIM Geomatics',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.3492183, -4.0551649]},
#   'description': 'Cantabria Office',
#   'address1': 'C/ Poeta JosÃ© LuÃ\xads Hidalgo, 5',
#   'address2': 'Con frente a Calle JesÃºs Cancio',
#   'zip_code': '39470',
#   'city': 'Torrelavega',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.3492183,
#   'longitude': -4.0551649},
#  {'name': 'Busuu',
#   'category_code': 'social',
#   'raised_amount': 4700000,
#   'location': {'type': 'Point', 'coordinates': [40.4225487, -3.6830316]},
#   'description': '',
#   'address1': 'Calle Columela 2, 1D',
#   'address2': '',
#   'zip_code': '28001',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4225487,
#   'longitude': -3.6830316},
#  {'name': 'tarifas24',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4304536, -3.7105118]},
#   'description': 'HQ',
#   'address1': '',
#   'address2': '',
#   'zip_code': '28015',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4304536,
#   'longitude': -3.7105118},
#  {'name': 'NTRglobal',
#   'category_code': 'enterprise',
#   'raised_amount': 34000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'NTR Head Office Barcelona',
#   'address1': 'Diagonal Litoral',
#   'address2': 'Josep Pla, 2 - Edificio B3, 1Âª Planta',
#   'zip_code': '08019',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Publicadigital',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4291944, -3.6768945]},
#   'description': '',
#   'address1': 'C/ General DÃ\xadaz Porlier 47, Bajo D',
#   'address2': '',
#   'zip_code': '28001',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4291944,
#   'longitude': -3.6768945},
#  {'name': 'Fotohoo',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.387917, 2.1699187]},
#   'description': 'Barcelona Headquarters',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.387917,
#   'longitude': 2.1699187},
#  {'name': 'Zed',
#   'category_code': None,
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ Zed Worldwide S.A.',
#   'address1': 'Complejo Europa Empresarial, C/ Rozabella 4, Ed. Bruselas',
#   'address2': '',
#   'zip_code': '28290',
#   'city': 'Las Rozas (Madrid)',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Nayatek',
#   'category_code': 'enterprise',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Nayatek EMEA',
#   'address1': 'Camino Cerro de los Gamos 1, Edif 1',
#   'address2': '28224 Pozuelo de AlarcÃ³n',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Central Reservations',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': "Passeig d'Amunt 7",
#   'address2': '(esq. c/ Escorial)',
#   'zip_code': '08024',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Ideup',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Headquarters',
#   'address1': 'Complejo Europa Empresarial. C/Playa de Liencres 2, Edificio Londres.',
#   'address2': '',
#   'zip_code': '28230',
#   'city': 'Las Rozaas',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Cierzo Development',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.6820833, -0.8874201]},
#   'description': '',
#   'address1': 'Maria de luna 11',
#   'address2': '',
#   'zip_code': '50017',
#   'city': 'Zaragoza',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.6820833,
#   'longitude': -0.8874201},
#  {'name': 'NetAsturias Internet',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.3459015, -5.36175]},
#   'description': 'NetAsturias Group',
#   'address1': 'Covadonga 12',
#   'address2': '',
#   'zip_code': '33530',
#   'city': 'Infiesto (Asturias)',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.3459015,
#   'longitude': -5.36175},
#  {'name': 'Entropy Computational Services',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4380872, -3.6760635]},
#   'description': 'World Headquarters',
#   'address1': 'C/ Madrid 10, 2-B',
#   'address2': 'Getafe',
#   'zip_code': '28901',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4380872,
#   'longitude': -3.6760635},
#  {'name': 'DialApplet',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Vidium',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Office',
#   'address1': 'Madrid 102 4ÂºB',
#   'address2': '',
#   'zip_code': '28902',
#   'city': 'Getafe',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Social Gaming Platform',
#   'category_code': 'network_hosting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4086268, -3.9970381]},
#   'description': 'Headquarters',
#   'address1': 'C/Alberto Juzdado 5',
#   'address2': '',
#   'zip_code': '28690',
#   'city': 'Brunete',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4086268,
#   'longitude': -3.9970381},
#  {'name': 'Sina ADI',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [43.4057593, -5.8063417]},
#   'description': 'Central',
#   'address1': 'avd/ GijÃ³n, 23',
#   'address2': '',
#   'zip_code': '33420',
#   'city': 'Lugones',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.4057593,
#   'longitude': -5.8063417},
#  {'name': 'Triforma - Innotiimi',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Madrid',
#   'address1': 'Antonio Suarez 10, blq A, local 302',
#   'address2': '',
#   'zip_code': '28802',
#   'city': 'AlcalÃ¡ de Henares',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Efebege',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [39.4502107, -0.3924646]},
#   'description': 'Efebege',
#   'address1': 'General Barroso, 66',
#   'address2': '',
#   'zip_code': '46017',
#   'city': 'Valencia',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 39.4502107,
#   'longitude': -0.3924646},
#  {'name': 'Unkasoft Advergaming',
#   'category_code': 'mobile',
#   'raised_amount': 1750000,
#   'location': {'type': 'Point', 'coordinates': [40.4474363, -3.6714915]},
#   'description': 'Madrid Office (marketing)',
#   'address1': 'Nieremberg 8, Bajo A',
#   'address2': '',
#   'zip_code': '28002',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4474363,
#   'longitude': -3.6714915},
#  {'name': 'citiservi',
#   'category_code': 'advertising',
#   'raised_amount': 2700000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'citiservi Madrid',
#   'address1': 'Barquillo 11, 4th Floor',
#   'address2': '',
#   'zip_code': 'ES-28045',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Voztelecom',
#   'category_code': 'public_relations',
#   'raised_amount': 2841000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ',
#   'address1': 'Avda. Parc Tecnologic 3',
#   'address2': 'Parque Tecnologico del Valles',
#   'zip_code': '08290',
#   'city': 'Cerdanyola',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Monema Communications',
#   'category_code': 'enterprise',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [42.4634876, -2.4476102]},
#   'description': 'Main Headquarters',
#   'address1': 'Gran Via 17',
#   'address2': '',
#   'zip_code': '26002',
#   'city': 'LogroÃ±o',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 42.4634876,
#   'longitude': -2.4476102},
#  {'name': 'Intergrid',
#   'category_code': 'network_hosting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3806494, 2.1687187]},
#   'description': 'Intergrid IDC',
#   'address1': "Carrer d'en Roig",
#   'address2': '',
#   'zip_code': '08001',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3806494,
#   'longitude': 2.1687187},
#  {'name': 'Feasa Valencia',
#   'category_code': 'hardware',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'R&D Spain Office',
#   'address1': 'Cami Vera SN',
#   'address2': 'Universidad Politecnica Valencia',
#   'zip_code': '46022',
#   'city': 'Valencia',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'SevenClick',
#   'category_code': 'mobile',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.6329538, -0.8809904]},
#   'description': 'HeadOffices',
#   'address1': 'Ronda del Canal Imperial de AragÃ³n 14',
#   'address2': '',
#   'zip_code': '50197',
#   'city': 'zaragoza',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.6329538,
#   'longitude': -0.8809904},
#  {'name': 'TravelCLICK',
#   'category_code': 'hospitality',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3850639, 2.1734035]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3850639,
#   'longitude': 2.1734035},
#  {'name': 'Nexway',
#   'category_code': 'ecommerce',
#   'raised_amount': 14000000,
#   'location': {'type': 'Point', 'coordinates': [40.4142986, -3.7033074]},
#   'description': 'Nexway Iberica',
#   'address1': 'C/ Duque de FernÃ¡n NÃºÃ±ez NÂº2 2Âº Oficina 2',
#   'address2': '',
#   'zip_code': '28012',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4142986,
#   'longitude': -3.7033074},
#  {'name': 'DAEDALUS - Data, Decisions and Language',
# ...
#   'country_code': 'ESP',
#   'latitude': 41.3803265,
#   'longitude': 2.1762262},
#  {'name': 'Velti',
#   'category_code': 'mobile',
#   'raised_amount': 32034118,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Madrid - Spain',
#   'address1': 'Parque Empresarial La Finca - Edificio 15A',
#   'address2': 'Paseo del Club Deportivo 1',
#   'zip_code': '28223',
#   'city': 'Pozuelo de Alarcon',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'RavenPack',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'R&D Center',
#   'address1': 'Urb. La Alzambra, v-2',
#   'address2': '',
#   'zip_code': '29660',
#   'city': 'Marbella',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'quimica_visual',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [41.3723033, 2.1560753]},
#   'description': 'Barcelona',
#   'address1': '',
#   'address2': '',
#   'zip_code': '08004',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3723033,
#   'longitude': 2.1560753},
#  {'name': 'JamesList',
#   'category_code': 'ecommerce',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [36.5099367, -4.8863523]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Marbella',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 36.5099367,
#   'longitude': -4.8863523},
#  {'name': 'Veeva',
#   'category_code': 'software',
#   'raised_amount': 4000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Europe Headquarters',
#   'address1': 'Avinguda Diagonal 420',
#   'address2': '',
#   'zip_code': '08037',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Virgin Play',
#   'category_code': 'games_video',
#   'raised_amount': 3860000,
#   'location': {'type': 'Point', 'coordinates': [40.4273082, -3.6895115]},
#   'description': 'Corporate Headquarters',
#   'address1': 'Paseo de la Castellana, 9-11',
#   'address2': '',
#   'zip_code': '28046',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4273082,
#   'longitude': -3.6895115},
#  {'name': 'Hostarting',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [39.8725119, -4.0210296]},
#   'description': 'Hostarting',
#   'address1': 'Recodo del Pinar 9',
#   'address2': '',
#   'zip_code': '45003',
#   'city': 'Toledo',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 39.8725119,
#   'longitude': -4.0210296},
#  {'name': 'Valentia Biopharma',
#   'category_code': 'biotech',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Parc cientific Universitat de valencia',
#   'address2': 'poligono industrial la coma s/n',
#   'zip_code': '46980',
#   'city': 'Paterna, Valencia',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'U-Play Studios',
#   'category_code': 'software',
#   'raised_amount': 651000,
#   'location': {'type': 'Point', 'coordinates': [41.4063346, 2.1920231]},
#   'description': 'Office',
#   'address1': 'C/Liacuna 162-164',
#   'address2': '08018 Barcelona',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.4063346,
#   'longitude': 2.1920231},
#  {'name': 'Iris Experience',
#   'category_code': 'advertising',
#   'raised_amount': 583000,
#   'location': {'type': 'Point', 'coordinates': [41.3927014, 2.156538]},
#   'description': '',
#   'address1': '186 RossellÃ³',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3927014,
#   'longitude': 2.156538},
#  {'name': 'iContainers',
#   'category_code': 'ecommerce',
#   'raised_amount': 150000,
#   'location': {'type': 'Point', 'coordinates': [41.3763043, 2.1752709]},
#   'description': 'Head Office',
#   'address1': 'Diputació 297',
#   'address2': '3º1º',
#   'zip_code': '08009',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 41.3763043,
#   'longitude': 2.1752709},
#  {'name': 'Undead Code Studios',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.6367104, -3.9980485]},
#   'description': 'Spain Headquarters',
#   'address1': '',
#   'address2': '',
#   'zip_code': '28400',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.6367104,
#   'longitude': -3.9980485},
#  {'name': 'Cokidoo',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [42.8995162, -8.5089455]},
#   'description': 'Santiago Office',
#   'address1': '',
#   'address2': '',
#   'zip_code': '15707',
#   'city': 'Santiago de Compostela',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 42.8995162,
#   'longitude': -8.5089455},
#  {'name': 'efectividads',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [39.4862314, -0.3574186]},
#   'description': 'AdLemons Headquarters',
#   'address1': 'Catedrático Agustín Escardino 9',
#   'address2': '',
#   'zip_code': '46980',
#   'city': 'Paterna, Valencia',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 39.4862314,
#   'longitude': -0.3574186},
#  {'name': 'IntraWorlds',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.426858, -3.7015237]},
#   'description': 'IntraWorlds, S.L.',
#   'address1': 'Fuencarral 93, 1d',
#   'address2': '',
#   'zip_code': '28004',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.426858,
#   'longitude': -3.7015237},
#  {'name': 'Chicisimo',
#   'category_code': 'fashion',
#   'raised_amount': 800000,
#   'location': {'type': 'Point', 'coordinates': [43.264499, -2.9308322]},
#   'description': 'Office',
#   'address1': 'Calle Henao 14',
#   'address2': 'nº 4, 4ºD',
#   'zip_code': '',
#   'city': 'Bilbao',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 43.264499,
#   'longitude': -2.9308322},
#  {'name': 'ERA Biotech',
#   'category_code': 'biotech',
#   'raised_amount': 12880000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Parc CientÃ\xadfic de Barcelona,',
#   'address2': 'Baldiri i Reixac, 15-21',
#   'zip_code': '08028',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'SearchCongress',
#   'category_code': 'other',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Netsize',
#   'category_code': 'mobile',
#   'raised_amount': 16780000,
#   'location': {'type': 'Point', 'coordinates': [40.4167413, -3.7032498]},
#   'description': '',
#   'address1': 'Av. Europa 19 2ª pta.',
#   'address2': '',
#   'zip_code': '28108',
#   'city': 'Alcobendas',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4167413,
#   'longitude': -3.7032498},
#  {'name': 'Meta4',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ',
#   'address1': 'Calle Rozabella, 8',
#   'address2': 'Centro Europa Empresarial Edificio Roma',
#   'zip_code': '28290',
#   'city': 'Las Rozas',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Tagmore Solutions',
#   'category_code': 'mobile',
#   'raised_amount': 250000,
#   'location': {'type': 'Point', 'coordinates': [40.4226918, -3.6883074]},
#   'description': 'Office',
#   'address1': 'Serrano 16',
#   'address2': 'First floor',
#   'zip_code': '28001',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4226918,
#   'longitude': -3.6883074},
#  {'name': 'Taxi Fares app',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4244585, -3.6990948]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '28004',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4244585,
#   'longitude': -3.6990948},
#  {'name': 'SEPMAG Technologies',
#   'category_code': 'biotech',
#   'raised_amount': 900000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'CENT. Parc Technologic del Valles',
#   'address2': 'Cardanyola del Valles',
#   'zip_code': 'E-08290',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'ticketea',
#   'category_code': 'ecommerce',
#   'raised_amount': 5730000,
#   'location': {'type': 'Point', 'coordinates': [40.4455155, -3.7061764]},
#   'description': 'Office',
#   'address1': 'Marques de Lema',
#   'address2': '7',
#   'zip_code': '28003',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4455155,
#   'longitude': -3.7061764},
#  {'name': 'Telefonica',
#   'category_code': 'public_relations',
#   'raised_amount': 743000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'HQ',
#   'address1': 'Distrito C Ronda de la Comunicación s/n',
#   'address2': '',
#   'zip_code': '28050',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Oesia',
#   'category_code': 'software',
#   'raised_amount': 56130000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'safecreative',
#   'category_code': None,
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Central Headquarters',
#   'address1': 'Bari Street 39 2nd floor',
#   'address2': 'Plaza',
#   'zip_code': '50197',
#   'city': 'Zaragoza',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'I6NET',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4342873, -3.7056763]},
#   'description': 'Corporate offices',
#   'address1': 'C/ Magallanes, 13',
#   'address2': '',
#   'zip_code': '28015',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4342873,
#   'longitude': -3.7056763},
#  {'name': 'cost4travel',
#   'category_code': 'web',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.4528711, -3.6149394]},
#   'description': 'Head office',
#   'address1': 'Calle Francisco Jose Arroyo, 6',
#   'address2': '',
#   'zip_code': '28042',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4528711,
#   'longitude': -3.6149394},
#  {'name': 'Genasys',
#   'category_code': 'software',
#   'raised_amount': 2780000,
#   'location': {'type': 'Point', 'coordinates': [40.4161835, -3.6988729]},
#   'description': '',
#   'address1': 'C/ Ventura de la Vega 5',
#   'address2': '28014 Madrid',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4161835,
#   'longitude': -3.6988729},
#  {'name': 'Colibria',
#   'category_code': 'public_relations',
#   'raised_amount': 10000000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Spain',
#   'address1': 'Avda. M-40, 15 Bj-7',
#   'address2': 'Pol. Ind. Ventorro del Cano - Edf. Skyline',
#   'zip_code': '28925',
#   'city': 'AlcorcÃ³n (Madrid)',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Readspeaker',
#   'category_code': 'software',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Pl. Catalunya 9,1a',
#   'address2': '',
#   'zip_code': '08002',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'FRV',
#   'category_code': 'cleantech',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'C/ Fortuny, 45 bajo izquierda',
#   'address2': '',
#   'zip_code': '28010',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'StreamUK',
#   'category_code': 'public_relations',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Spain',
#   'address1': 'c/marathon 6',
#   'address2': 'planta 1',
#   'zip_code': '28037',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Teambox',
#   'category_code': 'web',
#   'raised_amount': 6750000,
#   'location': {'type': 'Point', 'coordinates': [41.4063346, 2.1920231]},
#   'description': 'Barcelona Office',
#   'address1': 'Ronda Universitat 31',
#   'address2': '5o 4a',
#   'zip_code': '08007',
#   'city': 'Barcelona',
#   'state_code': 'CA',
#   'country_code': 'ESP',
#   'latitude': 41.4063346,
#   'longitude': 2.1920231},
#  {'name': 'SPOTI',
#   'category_code': 'games_video',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Madrid',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': '',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'Automatic Backlinks',
#   'category_code': 'search',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': 'Calle Jacques Cousteau 4 bajo',
#   'address2': '',
#   'zip_code': '18680',
#   'city': 'SalobreÃ±a, Granada',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'AdLINK Group',
#   'category_code': 'advertising',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'affilinet Spain',
#   'address1': 'affilinet Espana SLU',
#   'address2': 'VelÃ¡zquez 12, 7a-8a planta',
#   'zip_code': '28001',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'BuyVIP',
#   'category_code': 'ecommerce',
#   'raised_amount': 20000000,
#   'location': {'type': 'Point', 'coordinates': [40.4167413, -3.7032498]},
#   'description': 'Office',
#   'address1': '33. Edificio Atica 4 planta 2',
#   'address2': '28224 Pozuelo de AlarcÃ³n',
#   'zip_code': '',
#   'city': 'Madrid',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.4167413,
#   'longitude': -3.7032498},
#  {'name': 'International Sportsbook',
#   'category_code': 'mobile',
#   'raised_amount': 5380000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': '',
#   'address1': '',
#   'address2': '',
#   'zip_code': '',
#   'city': 'Barcelona',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None},
#  {'name': 'ITERNOVA',
#   'category_code': 'consulting',
#   'raised_amount': 0,
#   'location': {'type': 'Point', 'coordinates': [40.3401332, -1.1059614]},
#   'description': 'ITERNOVA TERUEL',
#   'address1': 'Plaza Goya 4 bajos',
#   'address2': '',
#   'zip_code': '44001',
#   'city': 'Teruel',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': 40.3401332,
#   'longitude': -1.1059614},
#  {'name': 'Xray Imatek',
#   'category_code': 'biotech',
#   'raised_amount': 300000,
#   'location': {'type': 'Point', 'coordinates': [None, None]},
#   'description': 'Office',
#   'address1': 'Edifici CM7 (IFAE). Campus UAB  Facultat de ciencies.',
#   'address2': '',
#   'zip_code': '08193',
#   'city': 'Bellaterra',
#   'state_code': None,
#   'country_code': 'ESP',
#   'latitude': None,
#   'longitude': None}]

# %% [markdown]
# ## Working with the new DataFrame:

# %%
spain_df = pd.DataFrame(final_offices)

# %%
spain_df.head()
# Out:
#          name category_code  raised_amount  \
# 0      Google        search      555182792
# 1    Truphone        mobile              0
# 2  Brightcove    enterprise      103100000
# 3  Negonation           web              0
# 4      TokBox     messaging       26000000
#
#                                             location       description  \
# 0     {'type': 'Point', 'coordinates': [None, None]}     Google Madrid
# 1     {'type': 'Point', 'coordinates': [None, None]}         Tru Spain
# 2     {'type': 'Point', 'coordinates': [None, None]}
# 3  {'type': 'Point', 'coordinates': [40.463667, -...              None
# 4     {'type': 'Point', 'coordinates': [None, None]}  Barcelona Office
#
#                  address1                     address2 zip_code  \
# 0           Torre Picasso   Plaza Pablo Ruiz Picasso 1    28020
# 1  Gran Via, 6. 4th floor                                 28013
# 2    Avenida Diagonal 640                     planta 6    08017
# 3
# 4  D00 BUILDING - P14-L11  PL.Ernest Lluch i Martin, 5
#
#                city state_code country_code   latitude  longitude
# 0            Madrid       None          ESP        NaN        NaN
# 1            Madrid       None          ESP        NaN        NaN
# 2         Barcelona       None          ESP        NaN        NaN
# 3                         None          ESP  40.463667   -3.74922
# 4  Barcelona, 08019       None          ESP        NaN        NaN

# %% [markdown]
# #### Let's clean the nulls:

# %%
spain_df = spain_df[spain_df["latitude"].isnull() == False]

# %%
# We drop the "state_code" column:

spain_df = spain_df.drop("state_code", axis = 1)

# %%
spain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129 entries, 3 to 216
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           129 non-null    object
#  1   category_code  128 non-null    object
#  2   raised_amount  129 non-null    int64
#  3   location       129 non-null    object
#  4   description    121 non-null    object
#  5   address1       129 non-null    object
#  6   address2       129 non-null    object
#  7   zip_code       129 non-null    object
#  8   city           129 non-null    object
#  9   country_code   129 non-null    object
#  10  latitude       129 non-null    float64
#  11  longitude      129 non-null    float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 13.1+ KB

# %%
spain_df = spain_df.reset_index(drop = True)

# %%
spain_df.head()
# Out:
#                        name category_code  raised_amount  \
# 0                Negonation           web              0
# 1                       Fon        mobile       44000000
# 2                     eyeOS    enterprise        1000000
# 3            ]project-open[      software              0
# 4  Starfish Community Group   advertising              0
#
#                                             location description  \
# 0  {'type': 'Point', 'coordinates': [40.463667, -...        None
# 1  {'type': 'Point', 'coordinates': [40.530724, -...
# 2  {'type': 'Point', 'coordinates': [41.3854855, ...          HQ
# 3  {'type': 'Point', 'coordinates': [41.383182, 2...
# 4  {'type': 'Point', 'coordinates': [41.387917, 2...
#
#                           address1 address2 zip_code       city country_code  \
# 0                                                                        ESP
# 1           Calle Quintanavides 15      2-1    28050     Madrid          ESP
# 2                 La Rambla 140 4C             08002  Barcelona          ESP
# 3  Ronda de Sant Antonã, 51, 1o 2a             08011  Barcelona          ESP
# 4          Major de Sarria 11, 2-1             08017  Barcelona          ESP
#
#     latitude  longitude
# 0  40.463667  -3.749220
# 1  40.530724  -3.632687
# 2  41.385486   2.170287
# 3  41.383182   2.163697
# 4  41.387917   2.169919

# %% [markdown]
# ## Now let's see each offices in a map with Folium:

# %%
inicial_lat = 40.60514229875771
inicial_long = -4.429541222343291

# %%
map_1 = folium.Map(location= [inicial_lat, inicial_long], zoom_start=6)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_209ab891d70a46d3a5dc8c6e161d4570%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_209ab891d70a46d3a5dc8c6e161d4570%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_209ab891d70a46d3a5dc8c6e161d4570%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_209ab891d70a46d3a5dc8c6e161d4570%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.60514229875771%2C%20-4.429541222343291%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
for i, row in spain_gdf.iterrows():
    loc = {
        "location":  [row["latitude"], row["longitude"]],
        "tooltip": row["name"]
    }
    
    icon = Icon(
    color="blue",
    prefix="fa",
    icon="briefcase",
    icon_color="black"
    )
    
    Marker(**loc, icon=icon).add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_209ab891d70a46d3a5dc8c6e161d4570%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_209ab891d70a46d3a5dc8c6e161d4570%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_209ab891d70a46d3a5dc8c6e161d4570%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_209ab891d70a46d3a5dc8c6e161d4570%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.60514229875771%2C%20-4.429541222343291%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### And let's export it as a JSON file:

# %%
spain_df.to_json("data/spain_companies.json", orient="records")
